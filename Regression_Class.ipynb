# %%
# https://github.com/NourozR/Stock-Price-Prediction-LSTM
# Apache 2.0 License

# %%
# %matplotlib inline

import math
import time
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from keras import Model
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Activation, LSTM, Dropout
from datetime import date, datetime, time, timedelta

print(tf.__version__)
# Out:
# 2.9.2

# %%
def new_dataset(dataset, step_size):
	data_X, data_Y = [], []
	for i in range(len(dataset)-step_size-1):
		a = dataset[i:(i+step_size), 0]
		data_X.append(a)
		data_Y.append(dataset[i + step_size, 0])
	return np.array(data_X), np.array(data_Y)

# %%
# Github에 올려둔 Dataset을 불러옴.
# !git clone https://github.com/kryowen/23W-OSSP.git

dataframe = pd.read_csv('/content/23W-OSSP/AAPL.csv', sep=',')
dataframe.reindex(index = dataframe.index[::-1])
dataset = dataframe.copy()

# Dataset에 저장된 상위의 레코드 5개를 보여줌.
dataset.head()
# Out:
# fatal: destination path '23W-OSSP' already exists and is not an empty directory.
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2010-01-04  7.622500  7.660714  7.585000  7.643214   6.515212  493729600
# 1  2010-01-05  7.664286  7.699643  7.616071  7.656429   6.526476  601904800
# 2  2010-01-06  7.656429  7.686786  7.526786  7.534643   6.422664  552160000
# 3  2010-01-07  7.562500  7.571429  7.466071  7.520714   6.410791  477131200
# 4  2010-01-08  7.510714  7.571429  7.466429  7.570714   6.453413  447610800

# %%
# Object 타입을 올바른 자료형으로 변경
dataset['Date'] = pd.to_datetime(dataset['Date'])
dataset['Open'] = np.array(dataset['Open'], dtype='float64')
dataset['High'] = np.array(dataset['High'], dtype='float64')
dataset['Low'] = np.array(dataset['Low'], dtype='float64')
dataset['Close'] = np.array(dataset['Close'], dtype='float64')
dataset['Adj Close'] = np.array(dataset['Adj Close'], dtype='float64')
dataset['Volume'] = np.array(dataset['Volume'], dtype='int64')

# %%
# NULL 값 확인
print(dataset.isna().sum())

# Dateset 확인
dataset.tail()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#            Date        Open        High         Low       Close   Adj Close  \
# 3255 2022-12-07  142.190002  143.369995  140.000000  140.940002  140.940002
# 3256 2022-12-08  142.360001  143.520004  141.100006  142.649994  142.649994
# 3257 2022-12-09  142.339996  145.570007  140.899994  142.160004  142.160004
# 3258 2022-12-12  142.699997  144.500000  141.059998  144.490005  144.490005
# 3259 2022-12-13  149.500000  149.970001  144.240005  145.470001  145.470001
#
#         Volume
# 3255  69721100
# 3256  62128300
# 3257  76069500
# 3258  70462700
# 3259  93831400

# %%
# data 정보 확인
dataset.describe().transpose()
# Out:
#             count          mean           std           min           25%  \
# Open       3260.0  5.099413e+01  4.714870e+01  6.870357e+00  1.895223e+01
# High       3260.0  5.156337e+01  4.775885e+01  7.000000e+00  1.909661e+01
# Low        3260.0  5.043574e+01  4.656118e+01  6.794643e+00  1.876518e+01
# Close      3260.0  5.102113e+01  4.718399e+01  6.858929e+00  1.895286e+01
# Adj Close  3260.0  4.916285e+01  4.764249e+01  5.846675e+00  1.661353e+01
# Volume     3260.0  2.568971e+08  2.227294e+08  3.519590e+07  1.027816e+08
#
#                     50%           75%           max
# Open       2.968000e+01  5.637625e+01  1.826300e+02
# High       2.991875e+01  5.689125e+01  1.829400e+02
# Low        2.945500e+01  5.566063e+01  1.791200e+02
# Close      2.974875e+01  5.617000e+01  1.820100e+02
# Adj Close  2.731521e+01  5.455201e+01  1.809597e+02
# Volume     1.674684e+08  3.463847e+08  1.880998e+09

# %%
# 예측에 사용될 지표 생성
# 상장일 ~ 데이터셋에 존재하는 날짜, Days
obs = np.arange(1, len(dataset) + 1, 1)

# 예측에 사용되는 각종 지표들
OHLC_avg = dataset[['Open', 'High', 'Low', 'Close']].mean(axis=1)
HLC_avg = dataset[['High', 'Low', 'Close']].mean(axis=1)
close_val = dataset['Close']

# %%
# 사용되는 지표들을 한번에 표시
plt.plot(obs, OHLC_avg, 'r', label = 'OHLC avg')
plt.plot(obs, HLC_avg, 'b', label = 'HLC avg')
plt.plot(obs, close_val, 'g', label = 'Closing price')
plt.legend(loc = 'upper right')
plt.show()

# %%
# 시계열 데이터로 준비
scaler = MinMaxScaler(feature_range=(0, 1))

OHLC_avg = np.reshape(OHLC_avg.values, (len(OHLC_avg), 1))
OHLC_avg = scaler.fit_transform(OHLC_avg)

# %%
# 준비된 시계열 Dataset을 Train Set과 Test Set으로 나눔 → Train : Test = 0.75 : 0.25
train_OHLC = int(len(OHLC_avg) * 0.75)
test_OHLC = len(OHLC_avg) - train_OHLC
train_OHLC, test_OHLC = OHLC_avg[:train_OHLC,:], OHLC_avg[train_OHLC:len(OHLC_avg),:]

# Dataset을 Feature와 Groundtruth로 분리
train_x, train_y = new_dataset(train_OHLC, 1)
test_x, test_y = new_dataset(test_OHLC, 1)

# Feature Reshaping
train_x = np.reshape(train_x, (train_x.shape[0], 1, train_x.shape[1]))
test_x = np.reshape(test_x, (test_x.shape[0], 1, test_x.shape[1]))
step_size = 1

# %%
# 클래스 모델
class myModel(Model):
    def __init__(self):
        super().__init__()
        self.r = Dense(1)
        self.act = Activation('linear')
        self.lstm1 = LSTM(32, input_shape=(1, step_size), dropout=0.25, return_sequences=True)
        self.lstm2 = LSTM(16, dropout=0.2)

    def call(self, input):
        x = self.lstm1(input)
        x = self.lstm2(x)
        x = self.r(x)
        return self.act(x)
    
model = myModel()

# %%
# 모델 컴파일, 모델 훈련
model.compile(loss='mean_squared_error', optimizer='adagrad')
model.fit(train_x, train_y, epochs=250, batch_size=1, verbose=2)
# Out:
# Epoch 1/250
# 2443/2443 - 15s - loss: 0.0087 - 15s/epoch - 6ms/step
# Epoch 2/250
# 2443/2443 - 8s - loss: 0.0058 - 8s/epoch - 3ms/step
# Epoch 3/250
# 2443/2443 - 6s - loss: 0.0054 - 6s/epoch - 3ms/step
# Epoch 4/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 5/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 6/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 7/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 8/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 9/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 10/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 11/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 12/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 13/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 14/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 15/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 16/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 17/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 18/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 19/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 20/250
# 2443/2443 - 5s - loss: 0.0053 - 5s/epoch - 2ms/step
# Epoch 21/250
# 2443/2443 - 8s - loss: 0.0053 - 8s/epoch - 3ms/step
# Epoch 22/250
# 2443/2443 - 8s - loss: 0.0052 - 8s/epoch - 3ms/step
# Epoch 23/250
# 2443/2443 - 8s - loss: 0.0052 - 8s/epoch - 3ms/step
# Epoch 24/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 25/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 26/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 27/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 28/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 29/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 30/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 31/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 32/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 33/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 34/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 35/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 36/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 37/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 38/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 39/250
# 2443/2443 - 6s - loss: 0.0052 - 6s/epoch - 3ms/step
# Epoch 40/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 41/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 42/250
# 2443/2443 - 5s - loss: 0.0052 - 5s/epoch - 2ms/step
# Epoch 43/250
# 2443/2443 - 6s - loss: 0.0052 - 6s/epoch - 2ms/step
# Epoch 44/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 45/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 46/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 47/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 48/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 49/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 50/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 51/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 52/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 53/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 54/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 55/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 56/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 57/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 58/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 59/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 60/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 61/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 62/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 63/250
# 2443/2443 - 5s - loss: 0.0051 - 5s/epoch - 2ms/step
# Epoch 64/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 65/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 66/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 67/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 68/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 69/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 70/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 71/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 72/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 73/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 74/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 75/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 76/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 77/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 78/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 79/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 80/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 81/250
# 2443/2443 - 5s - loss: 0.0050 - 5s/epoch - 2ms/step
# Epoch 82/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 83/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 84/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 85/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 86/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 87/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 88/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 89/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 90/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 91/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 92/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 93/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 94/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 95/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 96/250
# 2443/2443 - 5s - loss: 0.0049 - 5s/epoch - 2ms/step
# Epoch 97/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 98/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 99/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 100/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 101/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 102/250
# 2443/2443 - 7s - loss: 0.0048 - 7s/epoch - 3ms/step
# Epoch 103/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 104/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 105/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 106/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 107/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 108/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 109/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 110/250
# 2443/2443 - 5s - loss: 0.0048 - 5s/epoch - 2ms/step
# Epoch 111/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 112/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 113/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 114/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 115/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 116/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 117/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 118/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 119/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 120/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 121/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 122/250
# 2443/2443 - 5s - loss: 0.0047 - 5s/epoch - 2ms/step
# Epoch 123/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 124/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 125/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 126/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 127/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 128/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 129/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 130/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 131/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 132/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 133/250
# 2443/2443 - 5s - loss: 0.0046 - 5s/epoch - 2ms/step
# Epoch 134/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 135/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 136/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 137/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 138/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 139/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 140/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 141/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 142/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 143/250
# 2443/2443 - 5s - loss: 0.0045 - 5s/epoch - 2ms/step
# Epoch 144/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 145/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 146/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 147/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 148/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 149/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 150/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 151/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 152/250
# 2443/2443 - 5s - loss: 0.0044 - 5s/epoch - 2ms/step
# Epoch 153/250
# 2443/2443 - 5s - loss: 0.0043 - 5s/epoch - 2ms/step
# Epoch 154/250
# 2443/2443 - 5s - loss: 0.0043 - 5s/epoch - 2ms/step
# Epoch 155/250
# 2443/2443 - 5s - loss: 0.0043 - 5s/epoch - 2ms/step
# Epoch 156/250
# 2443/2443 - 5s - loss: 0.0043 - 5s/epoch - 2ms/step
# Epoch 157/250
# 2443/2443 - 5s - loss: 0.0043 - 5s/epoch - 2ms/step
# Epoch 158/250
# 2443/2443 - 5s - loss: 0.0043 - 5s/epoch - 2ms/step
# Epoch 159/250
# 2443/2443 - 5s - loss: 0.0043 - 5s/epoch - 2ms/step
# Epoch 160/250
# 2443/2443 - 5s - loss: 0.0043 - 5s/epoch - 2ms/step
# Epoch 161/250
# 2443/2443 - 5s - loss: 0.0042 - 5s/epoch - 2ms/step
# Epoch 162/250
# 2443/2443 - 5s - loss: 0.0042 - 5s/epoch - 2ms/step
# Epoch 163/250
# 2443/2443 - 5s - loss: 0.0042 - 5s/epoch - 2ms/step
# Epoch 164/250
# 2443/2443 - 5s - loss: 0.0042 - 5s/epoch - 2ms/step
# Epoch 165/250
# 2443/2443 - 7s - loss: 0.0042 - 7s/epoch - 3ms/step
# Epoch 166/250
# 2443/2443 - 5s - loss: 0.0042 - 5s/epoch - 2ms/step
# Epoch 167/250
# 2443/2443 - 5s - loss: 0.0042 - 5s/epoch - 2ms/step
# Epoch 168/250
# 2443/2443 - 5s - loss: 0.0042 - 5s/epoch - 2ms/step
# Epoch 169/250
# 2443/2443 - 5s - loss: 0.0041 - 5s/epoch - 2ms/step
# Epoch 170/250
# 2443/2443 - 5s - loss: 0.0041 - 5s/epoch - 2ms/step
# Epoch 171/250
# 2443/2443 - 5s - loss: 0.0041 - 5s/epoch - 2ms/step
# Epoch 172/250
# 2443/2443 - 5s - loss: 0.0041 - 5s/epoch - 2ms/step
# Epoch 173/250
# 2443/2443 - 5s - loss: 0.0041 - 5s/epoch - 2ms/step
# Epoch 174/250
# 2443/2443 - 5s - loss: 0.0041 - 5s/epoch - 2ms/step
# Epoch 175/250
# 2443/2443 - 5s - loss: 0.0041 - 5s/epoch - 2ms/step
# Epoch 176/250
# 2443/2443 - 5s - loss: 0.0040 - 5s/epoch - 2ms/step
# Epoch 177/250
# 2443/2443 - 5s - loss: 0.0040 - 5s/epoch - 2ms/step
# Epoch 178/250
# 2443/2443 - 5s - loss: 0.0040 - 5s/epoch - 2ms/step
# Epoch 179/250
# 2443/2443 - 5s - loss: 0.0040 - 5s/epoch - 2ms/step
# Epoch 180/250
# 2443/2443 - 5s - loss: 0.0040 - 5s/epoch - 2ms/step
# Epoch 181/250
# 2443/2443 - 5s - loss: 0.0040 - 5s/epoch - 2ms/step
# Epoch 182/250
# 2443/2443 - 6s - loss: 0.0040 - 6s/epoch - 2ms/step
# Epoch 183/250
# 2443/2443 - 9s - loss: 0.0039 - 9s/epoch - 4ms/step
# Epoch 184/250
# 2443/2443 - 8s - loss: 0.0039 - 8s/epoch - 3ms/step
# Epoch 185/250
# 2443/2443 - 7s - loss: 0.0039 - 7s/epoch - 3ms/step
# Epoch 186/250
# 2443/2443 - 5s - loss: 0.0039 - 5s/epoch - 2ms/step
# Epoch 187/250
# 2443/2443 - 6s - loss: 0.0039 - 6s/epoch - 2ms/step
# Epoch 188/250
# 2443/2443 - 6s - loss: 0.0039 - 6s/epoch - 3ms/step
# Epoch 189/250
# 2443/2443 - 6s - loss: 0.0038 - 6s/epoch - 2ms/step
# Epoch 190/250
# 2443/2443 - 6s - loss: 0.0038 - 6s/epoch - 3ms/step
# Epoch 191/250
# 2443/2443 - 5s - loss: 0.0038 - 5s/epoch - 2ms/step
# Epoch 192/250
# 2443/2443 - 5s - loss: 0.0038 - 5s/epoch - 2ms/step
# Epoch 193/250
# 2443/2443 - 5s - loss: 0.0038 - 5s/epoch - 2ms/step
# Epoch 194/250
# 2443/2443 - 5s - loss: 0.0038 - 5s/epoch - 2ms/step
# Epoch 195/250
# 2443/2443 - 5s - loss: 0.0037 - 5s/epoch - 2ms/step
# Epoch 196/250
# 2443/2443 - 5s - loss: 0.0037 - 5s/epoch - 2ms/step
# Epoch 197/250
# 2443/2443 - 5s - loss: 0.0037 - 5s/epoch - 2ms/step
# Epoch 198/250
# 2443/2443 - 5s - loss: 0.0037 - 5s/epoch - 2ms/step
# Epoch 199/250
# 2443/2443 - 6s - loss: 0.0037 - 6s/epoch - 3ms/step
# Epoch 200/250
# 2443/2443 - 5s - loss: 0.0037 - 5s/epoch - 2ms/step
# Epoch 201/250
# 2443/2443 - 5s - loss: 0.0036 - 5s/epoch - 2ms/step
# Epoch 202/250
# 2443/2443 - 6s - loss: 0.0036 - 6s/epoch - 3ms/step
# Epoch 203/250
# 2443/2443 - 7s - loss: 0.0036 - 7s/epoch - 3ms/step
# Epoch 204/250
# 2443/2443 - 5s - loss: 0.0036 - 5s/epoch - 2ms/step
# Epoch 205/250
# 2443/2443 - 5s - loss: 0.0036 - 5s/epoch - 2ms/step
# Epoch 206/250
# 2443/2443 - 6s - loss: 0.0036 - 6s/epoch - 3ms/step
# Epoch 207/250
# 2443/2443 - 6s - loss: 0.0035 - 6s/epoch - 2ms/step
# Epoch 208/250
# 2443/2443 - 5s - loss: 0.0035 - 5s/epoch - 2ms/step
# Epoch 209/250
# 2443/2443 - 5s - loss: 0.0035 - 5s/epoch - 2ms/step
# Epoch 210/250
# 2443/2443 - 5s - loss: 0.0035 - 5s/epoch - 2ms/step
# Epoch 211/250
# 2443/2443 - 5s - loss: 0.0035 - 5s/epoch - 2ms/step
# Epoch 212/250
# 2443/2443 - 5s - loss: 0.0034 - 5s/epoch - 2ms/step
# Epoch 213/250
# 2443/2443 - 5s - loss: 0.0034 - 5s/epoch - 2ms/step
# Epoch 214/250
# 2443/2443 - 5s - loss: 0.0034 - 5s/epoch - 2ms/step
# Epoch 215/250
# 2443/2443 - 5s - loss: 0.0034 - 5s/epoch - 2ms/step
# Epoch 216/250
# 2443/2443 - 5s - loss: 0.0034 - 5s/epoch - 2ms/step
# Epoch 217/250
# 2443/2443 - 5s - loss: 0.0033 - 5s/epoch - 2ms/step
# Epoch 218/250
# 2443/2443 - 5s - loss: 0.0033 - 5s/epoch - 2ms/step
# Epoch 219/250
# 2443/2443 - 5s - loss: 0.0033 - 5s/epoch - 2ms/step
# Epoch 220/250
# 2443/2443 - 5s - loss: 0.0033 - 5s/epoch - 2ms/step
# Epoch 221/250
# 2443/2443 - 6s - loss: 0.0033 - 6s/epoch - 3ms/step
# Epoch 222/250
# 2443/2443 - 5s - loss: 0.0032 - 5s/epoch - 2ms/step
# Epoch 223/250
# 2443/2443 - 5s - loss: 0.0032 - 5s/epoch - 2ms/step
# Epoch 224/250
# 2443/2443 - 5s - loss: 0.0032 - 5s/epoch - 2ms/step
# Epoch 225/250
# 2443/2443 - 5s - loss: 0.0032 - 5s/epoch - 2ms/step
# Epoch 226/250
# 2443/2443 - 5s - loss: 0.0032 - 5s/epoch - 2ms/step
# Epoch 227/250
# 2443/2443 - 5s - loss: 0.0031 - 5s/epoch - 2ms/step
# Epoch 228/250
# 2443/2443 - 5s - loss: 0.0031 - 5s/epoch - 2ms/step
# Epoch 229/250
# 2443/2443 - 5s - loss: 0.0031 - 5s/epoch - 2ms/step
# Epoch 230/250
# 2443/2443 - 5s - loss: 0.0031 - 5s/epoch - 2ms/step
# Epoch 231/250
# 2443/2443 - 5s - loss: 0.0030 - 5s/epoch - 2ms/step
# Epoch 232/250
# 2443/2443 - 5s - loss: 0.0030 - 5s/epoch - 2ms/step
# Epoch 233/250
# 2443/2443 - 5s - loss: 0.0030 - 5s/epoch - 2ms/step
# Epoch 234/250
# 2443/2443 - 5s - loss: 0.0030 - 5s/epoch - 2ms/step
# Epoch 235/250
# 2443/2443 - 5s - loss: 0.0030 - 5s/epoch - 2ms/step
# Epoch 236/250
# 2443/2443 - 5s - loss: 0.0029 - 5s/epoch - 2ms/step
# Epoch 237/250
# 2443/2443 - 5s - loss: 0.0029 - 5s/epoch - 2ms/step
# Epoch 238/250
# 2443/2443 - 5s - loss: 0.0029 - 5s/epoch - 2ms/step
# Epoch 239/250
# 2443/2443 - 5s - loss: 0.0029 - 5s/epoch - 2ms/step
# Epoch 240/250
# 2443/2443 - 5s - loss: 0.0028 - 5s/epoch - 2ms/step
# Epoch 241/250
# 2443/2443 - 5s - loss: 0.0028 - 5s/epoch - 2ms/step
# Epoch 242/250
# 2443/2443 - 5s - loss: 0.0028 - 5s/epoch - 2ms/step
# Epoch 243/250
# 2443/2443 - 5s - loss: 0.0028 - 5s/epoch - 2ms/step
# Epoch 244/250
# 2443/2443 - 5s - loss: 0.0027 - 5s/epoch - 2ms/step
# Epoch 245/250
# 2443/2443 - 5s - loss: 0.0027 - 5s/epoch - 2ms/step
# Epoch 246/250
# 2443/2443 - 5s - loss: 0.0027 - 5s/epoch - 2ms/step
# Epoch 247/250
# 2443/2443 - 5s - loss: 0.0027 - 5s/epoch - 2ms/step
# Epoch 248/250
# 2443/2443 - 5s - loss: 0.0026 - 5s/epoch - 2ms/step
# Epoch 249/250
# 2443/2443 - 5s - loss: 0.0026 - 5s/epoch - 2ms/step
# Epoch 250/250
# 2443/2443 - 5s - loss: 0.0026 - 5s/epoch - 2ms/step

# %%
# 훈련과 검정 데이터의 예측 실시
train_p = model.predict(train_x)
test_p = model.predict(test_x)
# Out:
# 77/77 [==============================] - 1s 2ms/step
# 26/26 [==============================] - 0s 2ms/step

# %%
# 예측된 데이터들을 반 정규화, 데이터의 단순성을 보장?
train_p = scaler.inverse_transform(train_p)
train_y = scaler.inverse_transform([train_y])

test_p = scaler.inverse_transform(test_p)
test_y = scaler.inverse_transform([test_y])

# %%
# 훈련 RMSE와 검정 RMSE 출력
train_score = math.sqrt(mean_squared_error(train_y[0], train_p[:,0]))
print('Train RMSE: %.2f' % (train_score))

test_score = math.sqrt(mean_squared_error(test_y[0], test_p[:,0]))
print('Test RMSE: %.2f' % (test_score))
# Out:
# Train RMSE: 8.86
# Test RMSE: 73.75

# %%
# 훈련 데이터 예측에 대한 그래프 생성
train_p_plot = np.empty_like(OHLC_avg)
train_p_plot[:, :] = np.nan
train_p_plot[step_size : len(train_p) + step_size, :] = train_p

# %%
# 검정 데이터 예측에 대한 그래프 생성
test_p_plot = np.empty_like(OHLC_avg)
test_p_plot[:, :] = np.nan
test_p_plot[len(train_p) + (step_size * 2) + 1 : len(OHLC_avg) - 1, :] = test_p

# %%
# 메인 Dataset 반정규화
OHLC_avg = scaler.inverse_transform(OHLC_avg)

# %%
plt.plot(OHLC_avg, 'g', label = 'original dataset')
plt.plot(train_p_plot, 'r', label = 'training set')
plt.plot(test_p_plot, 'b', label = 'predicted stock price/test set')
plt.legend(loc = 'upper right')
plt.xlabel('Time in Days')
plt.ylabel('OHLC Value of Apple Stocks')
plt.show()

# %%
plt.plot(train_p_plot, 'r', label = 'training set')
plt.plot(test_p_plot, 'b', label = 'predicted stock price/test set')
plt.legend(loc = 'upper right')
plt.xlabel('Time in Days')
plt.ylabel('OHLC Value of Apple Stocks')
plt.show()

# %%
last_val = test_p[-1]
last_val_scaled = last_val/last_val
next_val = model.predict(np.reshape(last_val_scaled, (1,1,1)))
print("Last Day Value:", last_val[0])
print("Next Day Value:", last_val[0] * next_val[0][0])
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Last Day Value: 60.428993
# Next Day Value: 21.781023
